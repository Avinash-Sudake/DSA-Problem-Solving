# %%
# Python Day - 9

# %%
# Function

# %%
# Function

def demo():
  #return "Hello Word"
  #print(10)
  return 10
 # print("Hello Word")

#demo()
print(demo())

# %%
# Write a program to use user defined fun that only adds two numbers

def add (4):
  print(4+5)
add()

# %%
# Write a program to create a function to find a square of 4

def sqr():
  return 4**2
print(sqr())

# %%
# Write a program use function to create a 7  num table

def table():
  for i in range(1,11):
    print(7*i)
table()

# %%
# Write A Program to find cube of a number
def cube(n):
  return n**3
print(cube(5))

# %%
# Write A Program to Add a two number

def add(a,b):
  return a+b
print("Addition :",add(2,5))
